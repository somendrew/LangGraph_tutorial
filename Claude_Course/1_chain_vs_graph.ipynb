# %% [markdown]
# <a href="https://colab.research.google.com/github/somendrew/LangGraph_tutorial/blob/main/1_chain_vs_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## What is it?
# * LangChain is a toolkit for building LLM-powered apps. It gives you tools for calling models, chaining prompts together, and connecting to external data.
# * LangGraph is a layer built on top of LangChain that lets you build LLM apps as graphs — where your logic flows through nodes and edges, supports loops, branches, and can even pause and wait for a human.
#
# ## Why does it matter?
#
# LangChain is great for simple, linear pipelines: do A, then B, then C.</br>
# But real-world AI agents need:
#
# * To loop (retry until the answer is good enough)
# * To branch (go left or right based on a condition)
# * To pause and ask a human for input
# * To remember what happened across multiple turns
#
# LangGraph gives you all of this. It treats your app like a flowchart you can run.

# %% [markdown]
# ![flowchart](images/langchain_vs_langgraph.svg)

# %%
from google.colab import userdata
api_key = userdata.get('api_key')

# %% [markdown]
# # LangChain Way

# %%
# !pip install -q langchain_core langchain_openai langgraph typing
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 27.2 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate


prompt = ChatPromptTemplate.from_messages([
    'user', "Answer this question :{question} "
])


llm = ChatOpenAI(model = "gpt-4o-mini",api_key = api_key)

chain = prompt | llm

result = chain.invoke({"question": "what is 2+2?"})

print(result.content)
# Out:
# 2 + 2 equals 4.

# %% [markdown]
# # LangGraph Way

# %%
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI
from typing import TypedDict



llm = ChatOpenAI(model='gpt-4o-mini',api_key = api_key)

#state: The data flow throught the graph
class State(TypedDict):
  question: str
  answer: str

#node: that take a state and return another state
def call_llm(state:State)-> State:
  response = llm.invoke(state['question'])
  return {"answer" : response.content}

#create graph
graph = StateGraph(State)
graph.add_node("call_llm",call_llm) #add node
graph.set_entry_point("call_llm") #where to start
graph.add_edge("call_llm", END) #Where to end

app = graph.compile()

result = app.invoke({"question": "what is 2+2?","answer": ""})
print(result['answer'])
# Out:
# 2 + 2 equals 4.

# %%
print(result)
# Out:
# {'question': 'what is 2+2?', 'answer': '2 + 2 equals 4.'}
